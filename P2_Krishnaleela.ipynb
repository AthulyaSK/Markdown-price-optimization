# %% [markdown]
# #Set-Up

# %%
#Copy-and-paste the code below to use as "set-up" when your optimization model uses Pyomo. 
#Uncomment the appropriate solver that you need.
#for reference, see https://colab.research.google.com/drive/1yGk8RB5NXrcx9f1Tb-oCiWzbxh61hZLI?usp=sharing

#installing and importing pyomo
# !pip install -q pyomo
from pyomo.environ import *

###installing and importing specific solvers (uncomment the one(s) you need)
###glpk
# !apt-get install -y -qq glpk-utils
###cbc
#!apt-get install -y -qq coinor-cbc
###ipopt
#!wget -N -q "https://ampl.com/dl/open/ipopt/ipopt-linux64.zip"
#!unzip -o -q ipopt-linux64
###bonmin
#!wget -N -q "https://ampl.com/dl/open/bonmin/bonmin-linux64.zip"
#!unzip -o -q bonmin-linux64
###couenne
#!wget -N -q "https://ampl.com/dl/open/couenne/couenne-linux64.zip"
#!unzip -o -q couenne-linux64
###geocode
#!wget -N -q "https://ampl.com/dl/open/gecode/gecode-linux64.zip"
#!unzip -o -q gecode-linux64

#Using the solvers:
#SolverFactory('glpk', executable='/usr/bin/glpsol')
#SolverFactory('cbc', executable='/usr/bin/cbc')
#SolverFactory('ipopt', executable='/content/ipopt')
#SolverFactory('bonmin', executable='/content/bonmin')
#SolverFactory('couenne', executable='/content/couenne')
#SolverFactory('gecode', executable='/content/gecode')
# Out:
#      |████████████████████████████████| 11.1 MB 3.7 MB/s
#      |████████████████████████████████| 49 kB 2.1 MB/s
# Selecting previously unselected package libsuitesparseconfig5:amd64.
# (Reading database ... 124015 files and directories currently installed.)
# Preparing to unpack .../libsuitesparseconfig5_1%3a5.1.2-2_amd64.deb ...
# Unpacking libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libamd2:amd64.
# Preparing to unpack .../libamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libcolamd2:amd64.
# Preparing to unpack .../libcolamd2_1%3a5.1.2-2_amd64.deb ...
# Unpacking libcolamd2:amd64 (1:5.1.2-2) ...
# Selecting previously unselected package libglpk40:amd64.
# Preparing to unpack .../libglpk40_4.65-1_amd64.deb ...
# Unpacking libglpk40:amd64 (4.65-1) ...
# Selecting previously unselected package glpk-utils.
# Preparing to unpack .../glpk-utils_4.65-1_amd64.deb ...
# Unpacking glpk-utils (4.65-1) ...
# Setting up libsuitesparseconfig5:amd64 (1:5.1.2-2) ...
# Setting up libcolamd2:amd64 (1:5.1.2-2) ...
# Setting up libamd2:amd64 (1:5.1.2-2) ...
# Setting up libglpk40:amd64 (4.65-1) ...
# Setting up glpk-utils (4.65-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
import pandas as pd

# %% [markdown]
# #Code that solves one instance of the Markdown Pricing Problem

# %%
#inputs
list_price = 55.48 #undiscounted price
demand = [120, 160, 194, 223] #for 0%, 15%, 30%, 50% discounts, respectively
weeksleft = 15 #current # of weeks left in the selling season
inv = 1421 #current amount of inventory left
sal = 13.87 #salvage value per unit

# %%
#calculate discounted prices
price = [list_price, list_price*(1-.15),list_price*(1-.3), list_price*(1-.5)] #for 0%, 15%, 30%, 50% discounts, respectively

#defining the optimization model
model = ConcreteModel()
model.x = Var(range(4), domain=NonNegativeReals)
model.Objective = Objective(expr = sum(demand[i]*model.x[i]*(price[i]-sal) for i in range(4)) + sal*inv, sense=maximize)
model.InvConstraint = Constraint(expr = sum(demand[i]*model.x[i] for i in range(4)) <= inv)
model.WeeksConstraint = Constraint(expr = sum(model.x[i] for i in range(4)) <= weeksleft)
model.pprint()
# Out:
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4993.2*x[0] + 5326.08*x[1] + 4843.404*x[2] + 3093.0099999999998*x[3] + 19709.27
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                      : Upper  : Active
#         None :  -Inf : 120*x[0] + 160*x[1] + 194*x[2] + 223*x[3] : 1421.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint

# %%
#solving
opt = SolverFactory('glpk')
opt.solve(model, tee=True)
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpvjhw3szg.glpk.raw --wglp /tmp/tmpwcundfyt.glpk.glp --cpxlp
#  /tmp/tmphuvt6kp0.pyomo.lp
# Reading problem data from '/tmp/tmphuvt6kp0.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpwcundfyt.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.230e+02  ratio =  2.230e+02
# GM: min|aij| =  8.565e-01  max|aij| =  1.168e+00  ratio =  1.363e+00
# EQ: min|aij| =  7.336e-01  max|aij| =  1.000e+00  ratio =  1.363e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   1.970927000e+04 inf =   0.000e+00 (4)
# *     2: obj =   7.883708000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpvjhw3szg.glpk.raw'...
# 17 lines were written
# {'Problem': [{'Name': 'unknown', 'Lower bound': 78837.08, 'Upper bound': 78837.08, 'Number of objectives': 1, 'Number of constraints': 3, 'Number of variables': 5, 'Number of nonzeros': 9, 'Sense': 'maximize'}], 'Solver': [{'Status': 'ok', 'Termination condition': 'optimal', 'Statistics': {'Branch and bound': {'Number of bounded subproblems': 0, 'Number of created subproblems': 0}}, 'Error rc': 0, 'Time': 0.013016939163208008}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}

# %%
#print results
print('optimal scheduled time at each price level over the remaining weeks: ', (model.x[0](), model.x[1](), model.x[2](), model.x[3]()))
print('projected optimal total revenue: ', model.Objective())
# Out:
# optimal scheduled time at each price level over the remaining weeks:  (11.8416666666667, 0.0, 0.0, 0.0)
# projected optimal total revenue:  78837.08000000016

# %% [markdown]
# ##1. Load the data

# %%
df=pd.read_excel('MP_scenarios.xlsx')

# %%
df.head()
# Out:
#    No  Price  Demand (0% discount)  Demand (15% discount)  \
# 0   1  55.48                   120                    160
# 1   2  53.68                   115                    149
# 2   3  61.56                   140                    191
# 3   4  65.72                   115                    151
# 4   5  64.98                   120                    173
#
#    Demand (30% discount)  Demand (50% discount)  Weeks Left  \
# 0                    194                    223          15
# 1                    171                    197          15
# 2                    207                    459          15
# 3                    242                    278          15
# 4                    221                    335          15
#
#    Inventory Remaining  Salvage Value
# 0                 1421         13.870
# 1                 2396         13.420
# 2                 2544         15.390
# 3                 1316         16.430
# 4                 1377         16.245

# %%
k=0 
rowdata = df.iloc[k].values.tolist()
data = [rowdata[1],
         rowdata[2:6],
         rowdata[6],rowdata[7],rowdata[8]]

# %% [markdown]
# ##2. Solves for optimal pricing plan and the resulting projected revenue

# %%
def solve(data):
  #discounted prices
  price = [data[0], data[0]*(1-.15),data[0]*(1-.3), data[0]*(1-.5)] #for 0%, 15%, 30%, 50% discounts, respectively
  demand=data[1]
  sal=data[4]
  inv=data[3]
  weeksleft=data[2]
  
  #optimization model
  model = ConcreteModel()
  model.x = Var(range(4), domain=NonNegativeReals)
  model.Objective = Objective(expr = sum(demand[i]*model.x[i]*(price[i]-sal) for i in range(4)) + sal*inv, sense=maximize)
  model.InvConstraint = Constraint(expr = sum(demand[i]*model.x[i] for i in range(4)) <= inv)
  model.WeeksConstraint = Constraint(expr = sum(model.x[i] for i in range(4)) <= weeksleft)
  model.pprint()

  #solve
  opt = SolverFactory('glpk')
  opt.solve(model, tee=True)
  objective=model.Objective()
  assignment_matrix = [[model.x[i]() for i in range(4)]]
  return assignment_matrix,objective

# %%
#Let's put it in a loop
outputs = []
for k in range(len(df)):
    rowdata = df.iloc[k].values.tolist()
    data = [rowdata[1],
         rowdata[2:6],
         rowdata[6],rowdata[7],rowdata[8]]
    outputs.append(solve(data))
# Out:
# Streaming output truncated to the last 5000 lines.
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.750e+02  ratio =  2.750e+02
# GM: min|aij| =  7.861e-01  max|aij| =  1.272e+00  ratio =  1.618e+00
# EQ: min|aij| =  6.179e-01  max|aij| =  1.000e+00  ratio =  1.618e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.405266000e+04 inf =   0.000e+00 (4)
# *     3: obj =   1.400234681e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpidc12nc_.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5996.1*x[0] + 6590.495999999998*x[1] + 5850.107999999999*x[2] + 6812.96*x[3] + 23306.579999999998
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 115.0*x[0] + 158.0*x[1] + 187.0*x[2] + 392.0*x[3] : 1341.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpw2jy1dhh.glpk.raw --wglp /tmp/tmplyzatv0z.glpk.glp --cpxlp
#  /tmp/tmpf7qs0kvi.pyomo.lp
# Reading problem data from '/tmp/tmpf7qs0kvi.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmplyzatv0z.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.920e+02  ratio =  3.920e+02
# GM: min|aij| =  7.360e-01  max|aij| =  1.359e+00  ratio =  1.846e+00
# EQ: min|aij| =  5.416e-01  max|aij| =  1.000e+00  ratio =  1.846e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.330658000e+04 inf =   0.000e+00 (4)
# *     2: obj =   9.322632000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpw2jy1dhh.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5635.499999999999*x[0] + 6311.759999999998*x[1] + 6138.359999999999*x[2] + 5332.05*x[3] + 14955.75
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 130.0*x[0] + 182.0*x[1] + 236.0*x[2] + 369.0*x[3] : 1035.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp1yyopaj9.glpk.raw --wglp /tmp/tmporloequ3.glpk.glp --cpxlp
#  /tmp/tmpkedofy69.pyomo.lp
# Reading problem data from '/tmp/tmpkedofy69.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmporloequ3.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.690e+02  ratio =  3.690e+02
# GM: min|aij| =  7.704e-01  max|aij| =  1.298e+00  ratio =  1.685e+00
# EQ: min|aij| =  5.936e-01  max|aij| =  1.000e+00  ratio =  1.685e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   1.495575000e+04 inf =   0.000e+00 (4)
# *     2: obj =   5.982300000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmp1yyopaj9.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5227.2*x[0] + 5322.240000000001*x[1] + 5132.16*x[2] + 5052.96*x[3] + 32931.36
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 110.0*x[0] + 140.0*x[1] + 180.0*x[2] + 319.0*x[3] : 2079.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpalrcesct.glpk.raw --wglp /tmp/tmpk41bggzn.glpk.glp --cpxlp
#  /tmp/tmpb37efx6h.pyomo.lp
# Reading problem data from '/tmp/tmpb37efx6h.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpk41bggzn.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.190e+02  ratio =  3.190e+02
# GM: min|aij| =  7.663e-01  max|aij| =  1.305e+00  ratio =  1.703e+00
# EQ: min|aij| =  5.872e-01  max|aij| =  1.000e+00  ratio =  1.703e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.293136000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.126984320e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpalrcesct.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6879.6*x[0] + 7469.28*x[1] + 7842.744*x[2] + 10909.08*x[3] + 44045.82
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 190.0*x[1] + 266.0*x[2] + 666.0*x[3] : 2689.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp54lr48g3.glpk.raw --wglp /tmp/tmplncqj_y0.glpk.glp --cpxlp
#  /tmp/tmp_1z_87g4.pyomo.lp
# Reading problem data from '/tmp/tmp_1z_87g4.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmplncqj_y0.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  6.660e+02  ratio =  6.660e+02
# GM: min|aij| =  6.771e-01  max|aij| =  1.477e+00  ratio =  2.181e+00
# EQ: min|aij| =  4.585e-01  max|aij| =  1.000e+00  ratio =  2.181e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.404582000e+04 inf =   0.000e+00 (4)
# *     3: obj =   1.541862504e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmp54lr48g3.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5441.85*x[0] + 5554.4400000000005*x[1] + 4683.744000000001*x[2] + 2989.89*x[3] + 22330.35
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 145.0*x[0] + 185.0*x[1] + 208.0*x[2] + 239.0*x[3] : 1785.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpty45ykr0.glpk.raw --wglp /tmp/tmpmtgxt30a.glpk.glp --cpxlp
#  /tmp/tmpi5p38k6p.pyomo.lp
# Reading problem data from '/tmp/tmpi5p38k6p.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpmtgxt30a.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.390e+02  ratio =  2.390e+02
# GM: min|aij| =  8.826e-01  max|aij| =  1.133e+00  ratio =  1.284e+00
# EQ: min|aij| =  7.789e-01  max|aij| =  1.000e+00  ratio =  1.284e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.233035000e+04 inf =   0.000e+00 (4)
# *     2: obj =   8.932140000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpty45ykr0.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5255.625*x[0] + 5415.396000000001*x[1] + 5322.896999999999*x[2] + 3405.645*x[3] + 39396.165
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 125.0*x[0] + 161.0*x[1] + 211.0*x[2] + 243.0*x[3] : 2811.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpz5if87jn.glpk.raw --wglp /tmp/tmpz6szlfv3.glpk.glp --cpxlp
#  /tmp/tmpq52scukl.pyomo.lp
# Reading problem data from '/tmp/tmpq52scukl.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpz6szlfv3.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.430e+02  ratio =  2.430e+02
# GM: min|aij| =  8.469e-01  max|aij| =  1.181e+00  ratio =  1.394e+00
# EQ: min|aij| =  7.172e-01  max|aij| =  1.000e+00  ratio =  1.394e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.939616500e+04 inf =   0.000e+00 (4)
# *     1: obj =   1.206271050e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpz5if87jn.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5285.700000000001*x[0] + 5134.68*x[1] + 5164.884*x[2] + 6707.805*x[3] + 37301.94
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 170.0*x[1] + 228.0*x[2] + 533.0*x[3] : 2964.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp9ox0ao9_.glpk.raw --wglp /tmp/tmpqnn6j7y_.glpk.glp --cpxlp
#  /tmp/tmpsulfnmn1.pyomo.lp
# Reading problem data from '/tmp/tmpsulfnmn1.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpqnn6j7y_.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  5.330e+02  ratio =  5.330e+02
# GM: min|aij| =  7.159e-01  max|aij| =  1.397e+00  ratio =  1.951e+00
# EQ: min|aij| =  5.125e-01  max|aij| =  1.000e+00  ratio =  1.951e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.730194000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.197138998e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmp9ox0ao9_.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5520.000000000001*x[0] + 6111.744000000001*x[1] + 5829.120000000001*x[2] + 6668.16*x[3] + 42202.240000000005
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 125.0*x[0] + 173.0*x[1] + 220.0*x[2] + 453.0*x[3] : 2867.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpv00fd3j9.glpk.raw --wglp /tmp/tmprnrxrae1.glpk.glp --cpxlp
#  /tmp/tmpnkwayaas.pyomo.lp
# Reading problem data from '/tmp/tmpnkwayaas.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmprnrxrae1.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.530e+02  ratio =  4.530e+02
# GM: min|aij| =  7.248e-01  max|aij| =  1.380e+00  ratio =  1.904e+00
# EQ: min|aij| =  5.253e-01  max|aij| =  1.000e+00  ratio =  1.904e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.220224000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.344189184e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpv00fd3j9.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5080.95*x[0] + 4877.711999999999*x[1] + 5429.357999999999*x[2] + 4484.139999999999*x[3] + 47099.6
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 105.0*x[0] + 126.0*x[1] + 187.0*x[2] + 278.0*x[3] : 2920.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp7f2jxt_9.glpk.raw --wglp /tmp/tmpk3bibput.glpk.glp --cpxlp
#  /tmp/tmpjlzl4e_8.pyomo.lp
# Reading problem data from '/tmp/tmpjlzl4e_8.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpk3bibput.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.780e+02  ratio =  2.780e+02
# GM: min|aij| =  7.839e-01  max|aij| =  1.276e+00  ratio =  1.627e+00
# EQ: min|aij| =  6.146e-01  max|aij| =  1.000e+00  ratio =  1.627e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.709960000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.285399700e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmp7f2jxt_9.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5854.275000000001*x[0] + 6140.484*x[1] + 5854.275*x[2] + 5738.635*x[3] + 37539.635
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 135.0*x[0] + 177.0*x[1] + 225.0*x[2] + 397.0*x[3] : 2597.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpl0rlbk9z.glpk.raw --wglp /tmp/tmpr698jcxp.glpk.glp --cpxlp
#  /tmp/tmpn03xazdv.pyomo.lp
# Reading problem data from '/tmp/tmpn03xazdv.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpr698jcxp.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.970e+02  ratio =  3.970e+02
# GM: min|aij| =  7.636e-01  max|aij| =  1.310e+00  ratio =  1.715e+00
# EQ: min|aij| =  5.831e-01  max|aij| =  1.000e+00  ratio =  1.715e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.753963500e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.292516540e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpl0rlbk9z.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6352.5*x[0] + 5336.099999999999*x[1] + 4682.699999999999*x[2] + 6776.0*x[3] + 32049.875
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 147.0*x[1] + 172.0*x[2] + 448.0*x[3] : 2119.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpriwlnkg2.glpk.raw --wglp /tmp/tmp0pef135e.glpk.glp --cpxlp
#  /tmp/tmp5_45rr82.pyomo.lp
# Reading problem data from '/tmp/tmp5_45rr82.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmp0pef135e.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.480e+02  ratio =  4.480e+02
# GM: min|aij| =  7.477e-01  max|aij| =  1.337e+00  ratio =  1.789e+00
# EQ: min|aij| =  5.590e-01  max|aij| =  1.000e+00  ratio =  1.789e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.204987500e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.273635000e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpriwlnkg2.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5434.8*x[0] + 5403.744*x[1] + 5706.54*x[2] + 3649.08*x[3] + 37370.72
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 174.0*x[1] + 245.0*x[2] + 282.0*x[3] : 2888.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpc_f6drhq.glpk.raw --wglp /tmp/tmpscd716xj.glpk.glp --cpxlp
#  /tmp/tmppulx09ot.pyomo.lp
# Reading problem data from '/tmp/tmppulx09ot.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpscd716xj.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.820e+02  ratio =  2.820e+02
# GM: min|aij| =  8.394e-01  max|aij| =  1.191e+00  ratio =  1.419e+00
# EQ: min|aij| =  7.046e-01  max|aij| =  1.000e+00  ratio =  1.419e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.737072000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.209320640e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpc_f6drhq.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4509.0*x[0] + 4905.7919999999995*x[1] + 5491.961999999999*x[2] + 6492.96*x[3] + 20155.23
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 100.0*x[0] + 136.0*x[1] + 203.0*x[2] + 432.0*x[3] : 1341.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpe_3n8cw0.glpk.raw --wglp /tmp/tmp86ekbavb.glpk.glp --cpxlp
#  /tmp/tmpkg7_foh9.pyomo.lp
# Reading problem data from '/tmp/tmpkg7_foh9.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmp86ekbavb.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.320e+02  ratio =  4.320e+02
# GM: min|aij| =  6.936e-01  max|aij| =  1.442e+00  ratio =  2.078e+00
# EQ: min|aij| =  4.811e-01  max|aij| =  1.000e+00  ratio =  2.078e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.015523000e+04 inf =   0.000e+00 (4)
# *     2: obj =   8.062092000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpe_3n8cw0.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4505.7*x[0] + 4544.88*x[1] + 4678.091999999999*x[2] + 6464.7*x[3] + 29398.06
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 115.0*x[0] + 145.0*x[1] + 199.0*x[2] + 495.0*x[3] : 2251.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpvhiu2591.glpk.raw --wglp /tmp/tmpuo1szvkw.glpk.glp --cpxlp
#  /tmp/tmpncnd0xfe.pyomo.lp
# Reading problem data from '/tmp/tmpncnd0xfe.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpuo1szvkw.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.950e+02  ratio =  4.950e+02
# GM: min|aij| =  6.943e-01  max|aij| =  1.440e+00  ratio =  2.075e+00
# EQ: min|aij| =  4.820e-01  max|aij| =  1.000e+00  ratio =  2.075e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.939806000e+04 inf =   0.000e+00 (4)
# *     3: obj =   9.969522842e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpvhiu2591.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6274.8*x[0] + 6561.648*x[1] + 6857.459999999999*x[2] + 5049.72*x[3] + 28864.079999999998
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 183.0*x[1] + 255.0*x[2] + 338.0*x[3] : 1932.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpy_g2dcd5.glpk.raw --wglp /tmp/tmp9bbhwhgu.glpk.glp --cpxlp
#  /tmp/tmpgn1ks_6m.pyomo.lp
# Reading problem data from '/tmp/tmpgn1ks_6m.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmp9bbhwhgu.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.380e+02  ratio =  3.380e+02
# GM: min|aij| =  8.022e-01  max|aij| =  1.247e+00  ratio =  1.554e+00
# EQ: min|aij| =  6.436e-01  max|aij| =  1.000e+00  ratio =  1.554e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.886408000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.154563200e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpy_g2dcd5.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4636.8*x[0] + 4451.328*x[1] + 5272.704000000001*x[2] + 3974.4*x[3] + 27997.440000000002
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 105.0*x[0] + 126.0*x[1] + 199.0*x[2] + 270.0*x[3] : 1902.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpk0e3grpq.glpk.raw --wglp /tmp/tmpzvcww99d.glpk.glp --cpxlp
#  /tmp/tmpacdmyq71.pyomo.lp
# Reading problem data from '/tmp/tmpacdmyq71.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpzvcww99d.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.700e+02  ratio =  2.700e+02
# GM: min|aij| =  7.897e-01  max|aij| =  1.266e+00  ratio =  1.604e+00
# EQ: min|aij| =  6.236e-01  max|aij| =  1.000e+00  ratio =  1.604e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.799744000e+04 inf =   0.000e+00 (4)
# *     2: obj =   9.976157413e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpk0e3grpq.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6378.75*x[0] + 6614.999999999999*x[1] + 6548.8499999999985*x[2] + 4189.5*x[3] + 47234.25
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 135.0*x[0] + 175.0*x[1] + 231.0*x[2] + 266.0*x[3] : 2999.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp00gk2dmm.glpk.raw --wglp /tmp/tmpcw1rsn56.glpk.glp --cpxlp
#  /tmp/tmprvgi19se.pyomo.lp
# Reading problem data from '/tmp/tmprvgi19se.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpcw1rsn56.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.660e+02  ratio =  2.660e+02
# GM: min|aij| =  8.440e-01  max|aij| =  1.185e+00  ratio =  1.404e+00
# EQ: min|aij| =  7.124e-01  max|aij| =  1.000e+00  ratio =  1.404e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.723425000e+04 inf =   0.000e+00 (4)
# *     1: obj =   1.464592500e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmp00gk2dmm.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5943.75*x[0] + 6428.76*x[1] + 6590.4299999999985*x[2] + 6863.05*x[3] + 45933.299999999996
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 125.0*x[0] + 169.0*x[1] + 231.0*x[2] + 433.0*x[3] : 2898.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpst90ddtb.glpk.raw --wglp /tmp/tmpeutdk4ji.glpk.glp --cpxlp
#  /tmp/tmpiwfodo9p.pyomo.lp
# Reading problem data from '/tmp/tmpiwfodo9p.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpeutdk4ji.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.330e+02  ratio =  4.330e+02
# GM: min|aij| =  7.330e-01  max|aij| =  1.364e+00  ratio =  1.861e+00
# EQ: min|aij| =  5.373e-01  max|aij| =  1.000e+00  ratio =  1.861e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.593330000e+04 inf =   0.000e+00 (4)
# *     3: obj =   1.433112518e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpst90ddtb.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5099.85*x[0] + 5517.552*x[1] + 4575.294*x[2] + 2930.3900000000003*x[3] + 29854.36
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 105.0*x[0] + 142.0*x[1] + 157.0*x[2] + 181.0*x[3] : 1844.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpmcnxnsdq.glpk.raw --wglp /tmp/tmpxu_a8unz.glpk.glp --cpxlp
#  /tmp/tmpxyrdg_wj.pyomo.lp
# Reading problem data from '/tmp/tmpxyrdg_wj.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpxu_a8unz.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.810e+02  ratio =  1.810e+02
# GM: min|aij| =  8.727e-01  max|aij| =  1.146e+00  ratio =  1.313e+00
# EQ: min|aij| =  7.616e-01  max|aij| =  1.000e+00  ratio =  1.313e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.985436000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.093889164e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpmcnxnsdq.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5892.9*x[0] + 6527.5199999999995*x[1] + 5140.421999999999*x[2] + 3792.6099999999997*x[3] + 42292.89
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 130.0*x[0] + 180.0*x[1] + 189.0*x[2] + 251.0*x[3] : 2799.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpxf1k03qc.glpk.raw --wglp /tmp/tmpo1h4x8ko.glpk.glp --cpxlp
#  /tmp/tmpmfyla_53.pyomo.lp
# Reading problem data from '/tmp/tmpmfyla_53.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpo1h4x8ko.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.510e+02  ratio =  2.510e+02
# GM: min|aij| =  8.483e-01  max|aij| =  1.179e+00  ratio =  1.390e+00
# EQ: min|aij| =  7.197e-01  max|aij| =  1.000e+00  ratio =  1.390e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.229289000e+04 inf =   0.000e+00 (4)
# *     1: obj =   1.402056900e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpxf1k03qc.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
# ...
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4490.325*x[0] + 4858.103999999999*x[1] + 5696.298*x[2] + 3635.025*x[3] + 32330.34
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 105.0*x[0] + 142.0*x[1] + 222.0*x[2] + 255.0*x[3] : 2268.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmplvwkg0pd.glpk.raw --wglp /tmp/tmpoznkz3sw.glpk.glp --cpxlp
#  /tmp/tmpidinh9xz.pyomo.lp
# Reading problem data from '/tmp/tmpidinh9xz.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpoznkz3sw.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.550e+02  ratio =  2.550e+02
# GM: min|aij| =  8.011e-01  max|aij| =  1.248e+00  ratio =  1.558e+00
# EQ: min|aij| =  6.417e-01  max|aij| =  1.000e+00  ratio =  1.558e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.233034000e+04 inf =   0.000e+00 (4)
# *     3: obj =   1.068282858e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmplvwkg0pd.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4538.474999999999*x[0] + 4483.223999999999*x[1] + 4925.231999999999*x[2] + 3893.8799999999997*x[3] + 13352.324999999999
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 115.0*x[0] + 142.0*x[1] + 208.0*x[2] + 296.0*x[3] : 1015.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpsix3p1a3.glpk.raw --wglp /tmp/tmpdzesv0_a.glpk.glp --cpxlp
#  /tmp/tmpz258kjvj.pyomo.lp
# Reading problem data from '/tmp/tmpz258kjvj.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpdzesv0_a.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.960e+02  ratio =  2.960e+02
# GM: min|aij| =  7.895e-01  max|aij| =  1.267e+00  ratio =  1.604e+00
# EQ: min|aij| =  6.233e-01  max|aij| =  1.000e+00  ratio =  1.604e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   1.335232500e+04 inf =   0.000e+00 (4)
# *     1: obj =   5.340930000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpsix3p1a3.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 4581.675*x[0] + 5306.015999999999*x[1] + 4188.959999999999*x[2] + 6603.43*x[3] + 33744.4
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 105.0*x[0] + 152.0*x[1] + 160.0*x[2] + 454.0*x[3] : 2320.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpq2pggvvl.glpk.raw --wglp /tmp/tmp5s7g47cs.glpk.glp --cpxlp
#  /tmp/tmpy5nppexx.pyomo.lp
# Reading problem data from '/tmp/tmpy5nppexx.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmp5s7g47cs.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  4.540e+02  ratio =  4.540e+02
# GM: min|aij| =  6.935e-01  max|aij| =  1.442e+00  ratio =  2.079e+00
# EQ: min|aij| =  4.809e-01  max|aij| =  1.000e+00  ratio =  2.079e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   3.374440000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.135064829e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpq2pggvvl.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5491.875*x[0] + 5940.012*x[1] + 4665.896999999999*x[2] + 4364.21*x[3] + 21454.925
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 125.0*x[0] + 169.0*x[1] + 177.0*x[2] + 298.0*x[3] : 1465.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpor16mphc.glpk.raw --wglp /tmp/tmp4u_shr6e.glpk.glp --cpxlp
#  /tmp/tmpsapof3bw.pyomo.lp
# Reading problem data from '/tmp/tmpsapof3bw.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmp4u_shr6e.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.980e+02  ratio =  2.980e+02
# GM: min|aij| =  8.048e-01  max|aij| =  1.243e+00  ratio =  1.544e+00
# EQ: min|aij| =  6.477e-01  max|aij| =  1.000e+00  ratio =  1.544e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.145492500e+04 inf =   0.000e+00 (4)
# *     2: obj =   8.581970000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpor16mphc.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 5457.075*x[0] + 6563.543999999999*x[1] + 5938.802999999999*x[2] + 4541.29*x[3] + 17976.985
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 145.0*x[0] + 218.0*x[1] + 263.0*x[2] + 362.0*x[3] : 1433.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpfhlj182o.glpk.raw --wglp /tmp/tmpy7s5f7yb.glpk.glp --cpxlp
#  /tmp/tmpfq02vxtk.pyomo.lp
# Reading problem data from '/tmp/tmpfq02vxtk.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpy7s5f7yb.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.620e+02  ratio =  3.620e+02
# GM: min|aij| =  7.955e-01  max|aij| =  1.257e+00  ratio =  1.580e+00
# EQ: min|aij| =  6.329e-01  max|aij| =  1.000e+00  ratio =  1.580e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   1.797698500e+04 inf =   0.000e+00 (4)
# *     2: obj =   7.190794000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpfhlj182o.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6255.900000000001*x[0] + 6613.380000000001*x[1] + 6005.663999999999*x[2] + 4349.34*x[3] + 20182.725
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 140.0*x[0] + 185.0*x[1] + 224.0*x[2] + 292.0*x[3] : 1355.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpsq1_jgy1.glpk.raw --wglp /tmp/tmpwmxdy_no.glpk.glp --cpxlp
#  /tmp/tmpbkyy6exj.pyomo.lp
# Reading problem data from '/tmp/tmpbkyy6exj.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpwmxdy_no.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.920e+02  ratio =  2.920e+02
# GM: min|aij| =  8.321e-01  max|aij| =  1.202e+00  ratio =  1.444e+00
# EQ: min|aij| =  6.924e-01  max|aij| =  1.000e+00  ratio =  1.444e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   2.018272500e+04 inf =   0.000e+00 (4)
# *     2: obj =   8.073090000e+04 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmpsq1_jgy1.glpk.raw'...
# 17 lines were written
# 1 Set Declarations
#     x_index : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    4 : {0, 1, 2, 3}
#
# 1 Var Declarations
#     x : Size=4, Index=x_index
#         Key : Lower : Value : Upper : Fixed : Stale : Domain
#           0 :     0 :  None :  None : False :  True : NonNegativeReals
#           1 :     0 :  None :  None : False :  True : NonNegativeReals
#           2 :     0 :  None :  None : False :  True : NonNegativeReals
#           3 :     0 :  None :  None : False :  True : NonNegativeReals
#
# 1 Objective Declarations
#     Objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 6536.7*x[0] + 7049.951999999999*x[1] + 5548.932*x[2] + 5084.1*x[3] + 41883.3
#
# 2 Constraint Declarations
#     InvConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                              : Upper  : Active
#         None :  -Inf : 135.0*x[0] + 182.0*x[1] + 191.0*x[2] + 315.0*x[3] : 2595.0 :   True
#     WeeksConstraint : Size=1, Index=None, Active=True
#         Key  : Lower : Body                      : Upper : Active
#         None :  -Inf : x[0] + x[1] + x[2] + x[3] :  15.0 :   True
#
# 5 Declarations: x_index x Objective InvConstraint WeeksConstraint
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmplpw3q5s3.glpk.raw --wglp /tmp/tmpx2tngewp.glpk.glp --cpxlp
#  /tmp/tmpvm_5c1px.pyomo.lp
# Reading problem data from '/tmp/tmpvm_5c1px.pyomo.lp'...
# 3 rows, 5 columns, 9 non-zeros
# 35 lines were read
# Writing problem data to '/tmp/tmpx2tngewp.glpk.glp'...
# 28 lines were written
# GLPK Simplex Optimizer, v4.65
# 3 rows, 5 columns, 9 non-zeros
# Preprocessing...
# 2 rows, 4 columns, 8 non-zeros
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  3.150e+02  ratio =  3.150e+02
# GM: min|aij| =  8.091e-01  max|aij| =  1.236e+00  ratio =  1.528e+00
# EQ: min|aij| =  6.547e-01  max|aij| =  1.000e+00  ratio =  1.528e+00
# Constructing initial basis...
# Size of triangular part is 2
# *     0: obj =   4.188330000e+04 inf =   0.000e+00 (4)
# *     2: obj =   1.461583455e+05 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.0 Mb (40412 bytes)
# Writing basic solution to '/tmp/tmplpw3q5s3.glpk.raw'...
# 17 lines were written

# %% [markdown]
# ##3. Output CSV file with added two columns

# %%
#add the two columns to data frame
df['Optimized Plan'] = [outputs[i][0] for i in range(len(outputs))]
df['Projected revenue']=[outputs[i][1] for i in range(len(outputs))]

#df to csv
df.to_csv('P2_Krishnaleela.csv', index=False)
